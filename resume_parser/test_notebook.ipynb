# %%
import spacy
spacy_nlp_trf = spacy.load("en_core_web_trf")
from spacy import displacy

# %%
spacy.__version__
# Out:
# '3.3.0'

# %%
text="""Raushan Kumar

Samastipur, Bihar, India

raushankumar18@ece.iiitp.ac.in

+91-9708387178

linkedin.com/in/raushan-kumar-iiitp

Summary
An energetic and passionate college student pursuing B Tech in Electronics and Communication at Indian Institute
of Information Technology Pune. Aiming to use the knowledge that I have acquired from my coursework as well
as what I gained during my major Internship. I have highly proficient programming skills and experience in Data
Science and Web development using Django.

Experience

Data Scientist
Wolters Kluwer
Aug 2021 - Dec 2021 (5 months)
Work together with a team of dedicated experts in the field of Data Science to build the best API for the
Extraction of data from contractual PDFs.

Utilising my experience with Python to write new algorithms for XML parsing to process terabytes of
XML data into indexed form to produce new insights.

Optimised the Module Using Machine learning and other extraction techniques like RE to mark the files
for Bank of America which effectively reduce the false positive case by 20%.

Built the module using extensive Regular Expression to revalidate the Insurance/loan data.

Education

Indian Institute of Information Technology, Pune
B.Tech, Electronics & Communication Engineering
2018 - 2022
I am securing the highest CGPA i.e. 8.96 till the 6th semester.

Jawahar Navodaya Vidyalaya (JNV)
12th, Science
2015 - 2017
CBSE Board 82.4%

Jawahar Navodaya Vidyalaya (JNV)
10th, Matriculation
2010 - 2015
CBSE Board 10 CGPA without upgrading
Got the merit certificate from the Education Minister of India.

Raushan Kumar - page 1

 
 
 


Licenses & Certifications

ML using Python - Mass Tech Pvt Ltd

Data Analytics using Python - Indian Institute of Technology, Kharagpur

Building Web Applications in Django - University of Michigan
https://coursera.org/share/8a09ef143e1ae6f425cc11db70d23ae0

Web Application Technologies and Django - University of Michigan
https://coursera.org/share/b485d687dddd94447a80836b124f9546

Python for Everybody Specialization - University of Michigan
https://coursera.org/share/6df1e2bbed690f538f38d088482fde1e

Skills
C (Programming Language)   •   C++   •   Python (Programming Language)   •   Core Java   •   RDBMS   •  
Machine Learning   •   Natural Language Processing (NLP)   •   Django   •   Mobile Robotics   •   Data Structures

Honors & Awards

Certificate of Participation - School Game Federation of India
Oct 2015
Participated in 26th NVS NATIONAL BASKETBALL MEET-2015.

Certificate of Merit - Central Board of Secondary Education
May 2015
Securing perfect 10 CGPA in AISSE 2015.

National Rank 12 - Petrocoder
Nov 2021
Petrocoder Technology challenge 2021.

Raushan Kumar - page 2

"""

# %%
import glob
from resume_parser.utils import *
# import sys, os
# parent_dir = os.getcwd() # find the path to module a
# print(parent_dir)
# # Then go up one level to the common parent directory
# path = os.path.dirname(parent_dir)
# # Add the parent to sys.pah
# sys.path.append(path)

folderpath=r'mediafiles/resumes'
file = glob.glob(folderpath +"\\*.*")[0]  # All Typres of files.....
text=extract_text(file,'.'+file.split('.')[-1])
text
# Out:
# '                                                        INDIAN   INSTITUTE   OF                                     \n\nINFORMATION TECHNOLOGY \n\nRaushan Kumar                                                                 PUNE \n05/HB Morwa, Samastipur Bihar 848122               \nE-mail: raushankumar18@ece.iiitp.ac.in \nPhone: +91-9708387178 \n\nOrganized and dependable candidate successful at managing multiple priorities with a positive attitude. Willingness to \ntake on added responsibilities to meet team goals. \n\nEducation \n\nB.Tech, Electronics & Communication Engineering                                                                                                            2018-22 \nIIIT Pune, CGPA – 8.96/10 till 6th  Semester \n\n12th (Jawahar Navodaya Vidyalaya Birauli Samastipur BR)                                                                                                     2017 \nCBSE Board, 82.4%                  \n\n10th (Jawahar Navodaya Vidyalaya Birauli Samastipur BR )                                                                                                   2015  \nCBSE Board, 10 CGPA \n\nTechnical Skills \n\n\uf0b7  Programming Languages:  \n\no  Python \no \n C/C++ \no  Core Java \no  MATLAB \n\n\uf0b7  Packages: MS Office \n\nINTERNSHIP \n\n\uf0b7  Technologies:  \no  RDBMS \no  Machine Learning \no  NLP  \no  Django (Backend web Framework) \no  Robotics, IoT & Automation  \no  Solr (IR) \n\n\uf0b7  Data Scientist Intern @ Wolters Kluwer pvt ltd:                                                                  (August 2021-December 2021)                                                                                                                             \n\no  Collaborated with senior personnel in technical works which shows adaptability and delivery of Tasks on \n\ntime. \n\no  Designed and tested by generating the test case for API based on NLP for Data Extraction from contractual \n\npdfs as a product for the company. \n\no  Worked on manipulation of XML data having a hierarchy table of content. \no  Designed a regex-based hard model for the validation of data extraction from Insurance/loan pdfs. \no  Studied  extensively \nrepresentations. \n\nin  translating  complex  data  sets \n\nin  data  handling,  specializing \n\ninto  visual \n\no  Have worked on IR technologies Lucene & Solr. \n\nBest Projects \n\n\uf0b7  Oxime: A Healthcare web-app.  \n\nThis is a web-designed healthcare application for measuring SPO2 level and heart-beat using their smartphone’s \ncamera. This application is an alternative to Oximeter. Currently, this web application is hosted on \npythonanywhere.com. (link) \n\n \n  \n \n \n \n \n \n \n \n \n \n \n  \n \n\x0c \uf0b7  Robot Navigation using Arrows \n\nThis project is an example of Machine Learning automation. I have designed an image processing ML model for \nfollowing the signs. I have used region segmentation and split & merge techniques to achieve good accuracy for \nthe detection of arrows. \n\n\uf0b7  Self-Balancing Robot \n\nThis project is basically focused on balancing the Robot on two wheels which reflects the best controlling \nalgorithm. I have used the MPU-6050 sensor to get the real position and orientation of the Robot, by using the \ndata from this sensor, I have implemented a PID controller for balancing. \n\n\uf0b7 \n\nIoT: Introduction to Smart Health \n\nThis project is an insight of the upcoming Healthcare System. In this project after collecting the data, we are pre-\nprocessing it. The processed data is sent to an IoT Dashboard for visualization and detection of illness. we have \nused MQTT protocols and Google Firebase for data transmission. \n\nTrainings & Workshops \n\n\uf0b7   7days workshop on Robotics and automation                                                                                  DEC’ 2019 - JAN’ 2020 \n\uf0b7  Data Analytics using Python Workshop        AIYS-1 (C-CUBE CLUB IIT KGP)                      ...

# %%
        # paragraphs=[re.sub(r'\s+', ' ', text) for text in paragraphs]
        # paragraphs=[text.strip(' \n').replace('\n', ' ') for text in paragraphs]
import re
text=re.sub(r'\n+','\n',text)
text=text.replace('\n',',')
text=re.sub(r'\s+', ' ', text)

text
# Out:
# 'Raushan Kumar,Samastipur, Bihar, India,raushankumar18@ece.iiitp.ac.in,+91-9708387178,linkedin.com/in/raushan-kumar-iiitp,Summary,An energetic and passionate college student pursuing B Tech in Electronics and Communication at Indian Institute,of Information Technology Pune. Aiming to use the knowledge that I have acquired from my coursework as well,as what I gained during my major Internship. I have highly proficient programming skills and experience in Data,Science and Web development using Django.,Experience,Data Scientist,Wolters Kluwer,Aug 2021 - Dec 2021 (5 months),Work together with a team of dedicated experts in the field of Data Science to build the best API for the,Extraction of data from contractual PDFs.,Utilising my experience with Python to write new algorithms for XML parsing to process terabytes of,XML data into indexed form to produce new insights.,Optimised the Module Using Machine learning and other extraction techniques like RE to mark the files,for Bank of America which effectively reduce the false positive case by 20%.,Built the module using extensive Regular Expression to revalidate the Insurance/loan data.,Education,Indian Institute of Information Technology, Pune,B.Tech, Electronics & Communication Engineering,2018 - 2022,I am securing the highest CGPA i.e. 8.96 till the 6th semester.,Jawahar Navodaya Vidyalaya (JNV),12th, Science,2015 - 2017,CBSE Board 82.4%,Jawahar Navodaya Vidyalaya (JNV),10th, Matriculation,2010 - 2015,CBSE Board 10 CGPA without upgrading,Got the merit certificate from the Education Minister of India.,Raushan Kumar - page 1, , , ,Licenses & Certifications,ML using Python - Mass Tech Pvt Ltd,Data Analytics using Python - Indian Institute of Technology, Kharagpur,Building Web Applications in Django - University of Michigan,https://coursera.org/share/8a09ef143e1ae6f425cc11db70d23ae0,Web Application Technologies and Django - University of Michigan,https://coursera.org/share/b485d687dddd94447a80836b124f9546,Python for Everybody Specialization - University of Michigan,https://coursera.org/share/6df1e2bbed690f538f38d088482fde1e,Skills,C (Programming Language) • C++ • Python (Programming Language) • Core Java • RDBMS • ,Machine Learning • Natural Language Processing (NLP) • Django • Mobile Robotics • Data Structures,Honors & Awards,Certificate of Participation - School Game Federation of India,Oct 2015,Participated in 26th NVS NATIONAL BASKETBALL MEET-2015.,Certificate of Merit - Central Board of Secondary Education,May 2015,Securing perfect 10 CGPA in AISSE 2015.,National Rank 12 - Petrocoder,Nov 2021,Petrocoder Technology challenge 2021.,Raushan Kumar - page 2,'

# %%
doc=spacy_nlp_trf(text)
displacy.render(doc)
# Out:
# c:\Users\niral\anaconda3\lib\site-packages\torch\autocast_mode.py:162: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="1aad5e5078524a5ab401cb992f9194d7-0" class="displacy" width="75125" height="4512.0" direction="ltr" style="max-width: none; height: 4512.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="4422.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Raushan</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="4422.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">Kumar</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="4422.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">
#
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="4422.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">Samastipur,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="4422.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">Bihar,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="4422.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">India</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="4422.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">
#
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="4422.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">raushankumar18@ece.iiitp.ac.in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">X</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="4422.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">
#
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="4422.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">+91-</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">X</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="4422.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">9708387178</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="4422.0">
#     <tspan class="displacy-word" fill="currentColor" x="1975">
#
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="4422.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">linkedin.com/in/raushan-kumar-iiitp</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">X</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="4422.0">
#     <tspan class="displacy-word" fill="currentColor" x="2325">
#
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="4422.0">
#     <tspan class="displacy-word" fill="currentColor" x="2500">Summary</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="4422.0">
#     <tspan class="displacy-word" fill="currentColor" x="2675">
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="4422.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">An</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="4422.0">
#     <tspan class="displacy-word" fill="currentColor" x="3025">energetic</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="4422.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="4422.0">
#     <tspan class="displacy-word" fill="currentColor" x="3375">passionate</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="4422.0">
#     <tspan class="displacy-word" fill="currentColor" x="3550">college</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="4422.0">
#     <tspan class="displacy-word" fill="currentColor" x="3725">student</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="4422.0">
#     <tspan class="displacy-word" fill="currentColor" x="3900">pursuing</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="4422.0">
#     <tspan class="displacy-word" fill="currentColor" x="4075">B</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="4422.0">
#     <tspan class="displacy-word" fill="currentColor" x="4250">Tech</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="4422.0">
#     <tspan class="displacy-word" fill="currentColor" x="4425">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="4422.0">
#     <tspan class="displacy-word" fill="currentColor" x="4600">Electronics</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="4422.0">
#     <tspan class="displacy-word" fill="currentColor" x="4775">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="4422.0">
#     <tspan class="displacy-word" fill="currentColor" x="4950">Communication</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="4422.0">
#     <tspan class="displacy-word" fill="currentColor" x="5125">at</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5125">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="4422.0">
#     <tspan class="displ

# %%
for i in doc:
    print(i,i.ent_type_)

print([(ent.text, ent.label_) for ent in doc.ents])
# Out:
# Raushan PERSON
# Kumar PERSON
#
#
#
# Samastipur GPE
# ,
# Bihar GPE
# ,
# India GPE
#
#
#
# raushankumar18@ece.iiitp.ac.in
#
#
#
# +91
# -
# 9708387178
#
#
#
# linkedin.com/in/raushan-kumar-iiitp
#
#
#
# Summary
#
#
# An
# energetic
# and
# passionate
# college
# student
# pursuing
# B
# Tech
# in
# Electronics
# and
# Communication
# at
# Indian ORG
# Institute ORG
#
#  ORG
# of ORG
# Information ORG
# Technology ORG
# Pune ORG
# .
# Aiming
# to
# use
# the
# knowledge
# that
# I
# have
# acquired
# from
# my
# coursework
# as
# well
#
#
# as
# what
# I
# gained
# during
# my
# major
# Internship
# .
# I
# have
# highly
# proficient
# programming
# skills
# and
# experience
# in
# Data
#
#
# Science
# and
# Web
# development
# using
# Django
# .
#
#
#
# Experience
#
#
#
# Data
# Scientist
#
#
# Wolters PERSON
# Kluwer PERSON
#
#
# Aug DATE
# 2021 DATE
# - DATE
# Dec DATE
# 2021 DATE
# (
# 5 DATE
# months DATE
# )
#
#
# Work
# together
# with
# a
# team
# of
# dedicated
# experts
# in
# the
# field
# of
# Data
# Science
# to
# build
# the
# best
# API
# for
# the
#
#
# Extraction
# of
# data
# from
# contractual
# PDFs
# .
#
#
#
# Utilising
# my
# experience
# with
# Python
# to
# write
# new
# algorithms
# for
# XML
# parsing
# to
# process
# terabytes QUANTITY
# of
#
#
# XML
# data
# into
# indexed
# form
# to
# produce
# new
# insights
# .
#
#
#
# Optimised
# the
# Module
# Using
# Machine
# learning
# and
# other
# extraction
# techniques
# like
# RE
# to
# mark
# the
# files
#
#
# for
# Bank ORG
# of ORG
# America ORG
# which
# effectively
# reduce
# the
# false
# positive
# case
# by
# 20 PERCENT
# % PERCENT
# .
#
#
#
# Built
# the
# module
# using
# extensive
# Regular
# Expression
# to
# revalidate
# the
# Insurance
# /
# loan
# data
# .
#
#
#
# Education
#
#
#
# Indian ORG
# Institute ORG
# of ORG
# Information ORG
# Technology ORG
# ,
# Pune
#
#
# B.Tech
# ,
# Electronics
# &
# Communication
# Engineering
#
#
# 2018 DATE
# - DATE
# 2022 DATE
#
#
# I
# am
# securing
# the
# highest
# CGPA
# i.e.
# 8.96 CARDINAL
# till
# the DATE
# 6th DATE
# semester DATE
# .
#
#
#
# Jawahar ORG
# Navodaya ORG
# Vidyalaya ORG
# (
# JNV
# )
#
#
# 12th ORDINAL
# ,
# Science
#
#
# 2015 DATE
# - DATE
# 2017 DATE
#
#
# CBSE ORG
# Board ORG
# 82.4 PERCENT
# % PERCENT
#
#
#
# Jawahar ORG
# Navodaya ORG
# Vidyalaya ORG
# (
# JNV
# )
#
#
# 10th ORDINAL
# ,
# Matriculation
#
#
# 2010 DATE
# - DATE
# 2015 DATE
#
#
# CBSE ORG
# Board ORG
# 10 CARDINAL
# CGPA
# without
# upgrading
#
#
# Got
# the
# merit
# certificate
# from
# the
# Education
# Minister
# of
# India
# .
#
#
#
# Raushan PERSON
# Kumar PERSON
# -
# page
# 1
#
#
#
#
#
#
#
#
# Licenses
# &
# Certifications
#
#
#
# ML
# using
# Python
# -
# Mass ORG
# Tech ORG
# Pvt ORG
# Ltd ORG
#
#
#
# Data
# Analytics
# using
# Python
# -
# Indian
# Institute
# of
# Technology
# ,
# Kharagpur GPE
#
#
#
# Building
# Web
# Applications
# in
# Django
# -
# University ORG
# of ORG
# Michigan ORG
#
#
# https://coursera.org/share/8a09ef143e1ae6f425cc11db70d23ae0
#
#
#
# Web
# Application
# Technologies
# and
# Django
# -
# University
# of
# Michigan
#
#
# https://coursera.org/share/b485d687dddd94447a80836b124f9546
#
#
#
# Python
# for
# Everybody
# Specialization
# -
# University ORG
# of ORG
# Michigan ORG
#
#
# https://coursera.org/share/6df1e2bbed690f538f38d088482fde1e
#
#
#
# Skills
#
#
# C
# (
# Programming
# Language
# )
#
# •
#
# C++
#
# •
#
# Python
# (
# Programming
# Language
# )
#
# •
#
# Core
# Java
#
# •
#
# RDBMS
#
# •
#
#
# Machine
# Learning
#
# •
#
# Natural
# Language
# Processing
# (
# NLP
# )
#
# •
#
# Django
#
# •
#
# Mobile
# Robotics
#
# •
#
# Data
# Structures
#
#
#
# Honors
# &
# Awards
#
#
#
# Certificate
# of
# Participation
# -
# School ORG
# Game ORG
# Federation ORG
# of ORG
# India ORG
#
#
# Oct DATE
# 2015 DATE
#
#
# Participated
# in
# 26th ORDINAL
# NVS ORG
# NATIONAL
# BASKETBALL
# MEET-2015
# .
#
#
#
# Certificate
# of
# Merit
# -
# Central
# Board
# of
# Secondary
# Education
#
#
# May DATE
# 2015 DATE
#
#
# Securing
# perfect
# 10 CARDINAL
# CGPA
# in
# AISSE
# 2015 DATE
# .
#
#
#
# National
# Rank
# 12 CARDINAL
# -
# Petrocoder
#
#
# Nov DATE
# 2021 DATE
#
#
# Petrocoder
# Technology
# challenge
# 2021 DATE
# .
#
#
#
# Raushan PERSON
# Kumar PERSON
# -
# page
# 2 CARDINAL
#
#
#
# [('Raushan Kumar', 'PERSON'), ('Samastipur', 'GPE'), ('Bihar', 'GPE'), ('India', 'GPE'), ('Indian Institute\nof Information Technology Pune', 'ORG'), ('Wolters Kluwer', 'PERSON'), ('Aug 2021 - Dec 2021', 'DATE'), ('5 months', 'DATE'), ('terabytes', 'QUANTITY'), ('Bank of America', 'ORG'), ('20%', 'PERCENT'), ('Indian Institute of Information Technology', 'ORG'), ('2018 - 2022', 'DATE'), ('8.96', 'CARDINAL'), ('the 6th semester', 'DATE'), ('Jawahar Navodaya Vidyalaya', 'ORG'), ('12th', 'ORDINAL'), ('2015 - 2017', 'DATE'), ('CBSE Board', 'ORG'), ('82.4%', 'PERCENT'), ('Jawahar Navodaya Vidyalaya', 'ORG'), ('10th', 'ORDINAL'), ('2010 - 2015', 'DATE'), ('CBSE Board', 'ORG'), ('10', 'CARDINAL'), ('Raushan Kumar', 'PERSON'), ('Mass Tech Pvt Ltd', 'ORG'), ('Kharagpur', 'GPE'), ('University of Michigan', 'ORG'), ('University of Michigan', 'ORG'), ('School Game Federation of India', 'ORG'), ('Oct 2015', 'DATE'), ('26th', 'ORDINAL'), ('NVS', 'ORG'), ('May 2015', 'DATE'), ('10', 'CARDINAL'), ('2015', 'DATE'), ('12', 'CARDINAL'), ('Nov 2021', 'DATE'), ('2021', 'DATE'), ('Raushan Kumar', 'PERSON'), ('2', 'CARDINAL')]

# %%
from spacy.tokens import Token
valid_name_type=['Borrower','Seller','Lender','Contractor']
def is_valid_type(token):
    for word in valid_name_type:
            if word in token.text:
                return True
    else:
        return False 
def check_next(token):
    try:
        temp=token.nbor()
        if temp.pos_ in ['NOUN','PROPN'] and is_valid_type(temp):
            return True
        elif temp.pos_ =='PUNCT':
            return check_next(temp)
        else:
            return  False
    except:
        return False

Token.set_extension("is_valid_type", getter=is_valid_type,force=True)
Token.set_extension("check_ner", getter=lambda token: token.ent_type_ in ["ORG","PERSON"],force=True)
Token.set_extension("validate_pattern_1",getter=lambda token: token.pos_ in ["NOUN","PROPN"],force=True)
Token.set_extension("check_next", getter=check_next,force=True)

# %%
from spacy.matcher import DependencyMatcher

 

matcher = DependencyMatcher(spacy_nlp_trf.vocab,validate=True)

 
#force to detect borrower address....
pattern1_1 =[   
    {
        "RIGHT_ID": "name",
        "RIGHT_ATTRS":  {"POS": "PROPN","DEP":"conj","_":{"check_ner":True}}
    },
    {
        "LEFT_ID": "name",
        "REL_OP": ">>",
        "RIGHT_ID": "name_type",
        "RIGHT_ATTRS":{"POS":"PROPN", "_":{"is_valid_type":True}}
    }]#lender  # exception case lender with appos case from borrower


matcher.add("pattern_1", [pattern1_1])
matches = matcher(doc)
print(matches)
for match in matches:
    match_id, token_ids = match
    print(spacy_nlp_trf.vocab.strings[match_id])
    print('\nhere\n')
    for i in range(len(token_ids)):
        if pattern1_1[i]["RIGHT_ID"] in ['name','name_type']:
            print(pattern1_1[i]["RIGHT_ID"] + ":",
              " ".join(([doc[token_ids[i]].text]+[str(k) for k in doc[token_ids[i]].lefts if k.dep_=="compound"])[::-1]))
    print()
